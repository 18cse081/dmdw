# %% [markdown]
# <a href="https://colab.research.google.com/github/18cse081/dmdw/blob/main/Disimilarity_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/18cse005/DMDW/main/cwurData.csv")

# %%
df
# Out:
#       world_rank                            institution  ...   score  year
# 0              1                     Harvard University  ...  100.00  2012
# 1              2  Massachusetts Institute of Technology  ...   91.67  2012
# 2              3                    Stanford University  ...   89.50  2012
# 3              4                University of Cambridge  ...   86.17  2012
# 4              5     California Institute of Technology  ...   85.21  2012
# ...          ...                                    ...  ...     ...   ...
# 2195         996              University of the Algarve  ...   44.03  2015
# 2196         997                  Alexandria University  ...   44.03  2015
# 2197         998            Federal University of Ceará  ...   44.03  2015
# 2198         999                 University of A Coruña  ...   44.02  2015
# 2199        1000        China Pharmaceutical University  ...   44.02  2015
#
# [2200 rows x 14 columns]

# %% [markdown]
# Proximity measures of binary attributes

# %%
df1=df[['world_rank','institution','country','national_rank','quality_of_education','alumni_employment','quality_of_faculty','publications']]

# %%
df1.head()
# Out:
#    world_rank  ... publications
# 0           1  ...            1
# 1           2  ...           12
# 2           3  ...            4
# 3           4  ...           16
# 4           5  ...           37
#
# [5 rows x 8 columns]

# %%
df1=df1.replace("no",0)
df1=df1.replace("yes",1)

# %%
df1.head()
# Out:
#    world_rank  ... publications
# 0           1  ...            1
# 1           2  ...           12
# 2           3  ...            4
# 3           4  ...           16
# 4           5  ...           37
#
# [5 rows x 8 columns]

# %%
n=np.array(df1[['national_rank','quality_of_education']])
n=n.reshape(-1,2)
n.shape
# Out:
# (2200, 2)

# %%
m=np.array(df1[['publications','quality_of_faculty']])
m=m.reshape(-1,2)
m.shape
# Out:
# (2200, 2)

# %%
from scipy.spatial import distance
dist_matrix=distance.cdist(n,m)
print(dist_matrix)
# Out:
# [[  6.          11.70469991   3.60555128 ... 855.43088558 909.80547371
#   885.50607   ]
#  [  8.06225775  11.66190379   4.47213595 ... 853.97013999 908.37051912
#   884.05995272]
#  [ 16.1245155   16.64331698  12.04159458 ... 851.07578981 905.58820664
#   881.22925507]
#  ...
#  [366.39459603 364.04944719 362.27061708 ... 825.55738747 880.69574769
#   856.0665862 ]
#  [368.07200383 365.07533469 363.78565117 ... 803.92847941 859.02095434
#   834.41116963]
#  [375.07332616 370.85981179 370.519905   ... 761.71516986 816.70680173
#   792.13950792]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(dist_matrix)
plt.show()

# %%
# nominal attribute

# %%
nominal=df[['country','citations','broad_impact','patents']]
nominal=nominal.replace('United Kingdom','UK')
nominal=(nominal.astype('category'))

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
nominal['country']=lb.fit_transform(nominal['country'])
nominal['citations']=lb.fit_transform(nominal['citations'])
nominal['broad_impact']=lb.fit_transform(nominal['broad_impact'])
nominal['patents']=lb.fit_transform(nominal['patents'])

# %%
nominal.head()
# Out:
#    country  citations  broad_impact  patents
# 0       55          0           542        4
# 1       55          3           408        0
# 2       55          1           407       14
# 3       54         10           406       49
# 4       55         21           405       17

# %%
nominal1=np.array(nominal)
nominal1.reshape(-1,2)
nominal2=np.array(nominal)
nominal2.reshape(-1,2)
# Out:
# array([[ 55,   0],
#        [542,   4],
#        [ 55,   3],
#        ...,
#        [331, 633],
#        [  8, 134],
#        [333, 542]])

# %%
from scipy.spatial import distance
dist_matrix=distance.cdist(nominal1,nominal2)
print(dist_matrix)
# Out:
# [[  0.         134.09325114 135.37355724 ... 772.34642486 676.88034393
#   594.38203203]
#  [134.09325114   0.          14.17744688 ... 750.31993176 651.020737
#   564.58746001]
#  [135.37355724  14.17744688   0.         ... 736.9036572  637.71074948
#   551.50521303]
#  ...
#  [772.34642486 750.31993176 736.9036572  ...   0.         109.25200227
#   191.05234885]
#  [676.88034393 651.020737   637.71074948 ... 109.25200227   0.
#    99.4233373 ]
#  [594.38203203 564.58746001 551.50521303 ... 191.05234885  99.4233373
#     0.        ]]

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show>
